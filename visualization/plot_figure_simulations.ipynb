# %% [markdown]
# # Overview
#
# This notebook plots the main simulation figures for the CPI-DNN paper
#
# - _Figure 1_: High-level comparison of CPI and Perfmit
# - _Figure 2_: Effect of sample size
# - _Figure 3_: Extensive generative model benchmark, inclduding state of the art.
# - _Figure 4_: Application example

# %%
import pathlib
import numpy as np
import pandas as pd
import altair as alt
import warnings
warnings.filterwarnings("ignore")

# %%
res_path = pathlib.Path('../results/results_csv')
list(res_path.glob('*.csv'))
# Out:
# [PosixPath('../results/results_csv/time_bars_blocks_100_UKBB_single.csv'),
#  PosixPath('../results/results_csv/simulation_results_blocks_100_CPI_n_1000_p_50_cpi_depth_10.csv'),
#  PosixPath('../results/results_csv/simulation_results_blocks_100_allMethods_pred_final.csv'),
#  PosixPath('../results/results_csv/simulation_results_blocks_100_dnn_dnn_py_perm_100--1000.csv'),
#  PosixPath('../results/results_csv/time_bars_blocks_100_Mi_dnn_dnn_py_300:100.csv'),
#  PosixPath('../results/results_csv/type1error_blocks_100_CPI_LOCO_DNN.csv'),
#  PosixPath('../results/results_csv/simulation_results_blocks_100_CPI_n_1000_p_50_cpi_depth_4.csv'),
#  PosixPath('../results/results_csv/time_bars_blocks_100_n_10000_p_50_cpi_permfit.csv'),
#  PosixPath('../results/results_csv/type1error_blocks_100_dnn_dnn_py_perm_100--1000.csv'),
#  PosixPath('../results/results_csv/type1error_blocks_100_UKBB_single.csv'),
#  PosixPath('../results/results_csv/AUC_blocks_100_n_10000_p_50_cpi_permfit.csv'),
#  PosixPath('../results/results_csv/Result_single_FREQ_all_imp_outer_10_inner.csv'),
#  PosixPath('../results/results_csv/simulation_results_blocks_100_CPI_n_1000_p_50_cpi_depth_5.csv'),
#  PosixPath('../results/results_csv/AUC_blocks_100_Mi_dnn_dnn_py_300:100.csv'),
#  PosixPath('../results/results_csv/power_blocks_100_n_10000_p_50_cpi_permfit.csv'),
#  PosixPath('../results/results_csv/power_blocks_100_allMethods_pred_imp_final.csv'),
#  PosixPath('../results/results_csv/simulation_results_blocks_100_Mi_dnn_dnn_py_300:100.csv'),
#  PosixPath('../results/results_csv/simulation_results_blocks_100_CPI_n_1000_p_50_cpi_depth_1.csv'),
#  PosixPath('../results/results_csv/simulation_results_blocks_100_n_10000_p_50_cpi_permfit.csv'),
#  PosixPath('../results/results_csv/AUC_blocks_100_UKBB_single.csv'),
#  PosixPath('../results/results_csv/simulation_results_blocks_100_CPI_LOCO_DNN.csv'),
#  PosixPath('../results/results_csv/power_blocks_100_Mi_dnn_dnn_py_300:100.csv'),
#  PosixPath('../results/results_csv/type1error_blocks_100_allMethods_pred_imp_final.csv'),
#  PosixPath('../results/results_csv/simulation_results_blocks_100_UKBB_single.csv'),
#  PosixPath('../results/results_csv/AUC_blocks_100_allMethods_pred_imp_final_withoutPval.csv'),
#  PosixPath('../results/results_csv/Result_single_10Fold_FREQ_all_imp.csv'),
#  PosixPath('../results/results_csv/time_bars_blocks_100_allMethods_pred_imp_final.csv'),
#  PosixPath('../results/results_csv/power_blocks_100_UKBB_single.csv'),
#  PosixPath('../results/results_csv/AUC_blocks_100_allMethods_pred_imp_final_withPval.csv'),
#  PosixPath('../results/results_csv/simulation_results_blocks_100_CPI_n_1000_p_50_cpi_depth_2.csv'),
#  PosixPath('../results/results_csv/time_bars_blocks_100_CPI_LOCO_DNN.csv'),
#  PosixPath('../results/results_csv/type1error_blocks_100_n_10000_p_50_cpi_permfit.csv'),
#  PosixPath('../results/results_csv/type1error_blocks_100_Mi_dnn_dnn_py_300:100.csv'),
#  PosixPath('../results/results_csv/AUC_blocks_100_CPI_LOCO_DNN.csv'),
#  PosixPath('../results/results_csv/AUC_blocks_100_dnn_dnn_py_perm_100--1000.csv'),
#  PosixPath('../results/results_csv/power_blocks_100_CPI_LOCO_DNN.csv'),
#  PosixPath('../results/results_csv/simulation_results_blocks_100_CPI_n_1000_p_50_cpi_depth_3.csv')]

# %% [markdown]
# ## Figure 1

# %%
res_path = pathlib.Path('../results/results_csv')
list(res_path.glob('*Mi*.csv'))
# Out:
# [PosixPath('../results/results_csv/time_bars_blocks_100_Mi_dnn_dnn_py_300:100.csv'),
#  PosixPath('../results/results_csv/AUC_blocks_100_Mi_dnn_dnn_py_300:100.csv'),
#  PosixPath('../results/results_csv/simulation_results_blocks_100_Mi_dnn_dnn_py_300:100.csv'),
#  PosixPath('../results/results_csv/power_blocks_100_Mi_dnn_dnn_py_300:100.csv'),
#  PosixPath('../results/results_csv/type1error_blocks_100_Mi_dnn_dnn_py_300:100.csv')]

# %%
df_auc = pd.read_csv(res_path / 'AUC_blocks_100_Mi_dnn_dnn_py_300:100.csv')
df_t1_error = pd.read_csv(res_path / 'type1error_blocks_100_Mi_dnn_dnn_py_300:100.csv')

# %%
df_auc
# Out:
#      Unnamed: 0       Method  correlation  n_samples        prob_data  \
# 0             1  Permfit-DNN          0.0        300  regression_perm
# 1             2  Permfit-DNN          0.0        300  regression_perm
# 2             3  Permfit-DNN          0.0        300  regression_perm
# 3             4  Permfit-DNN          0.0        300  regression_perm
# 4             5  Permfit-DNN          0.0        300  regression_perm
# ..          ...          ...          ...        ...              ...
# 795         796      CPI-DNN          0.8        300  regression_perm
# 796         797      CPI-DNN          0.8        300  regression_perm
# 797         798      CPI-DNN          0.8        300  regression_perm
# 798         799      CPI-DNN          0.8        300  regression_perm
# 799         800      CPI-DNN          0.8        300  regression_perm
#
#      iteration        V1
# 0            1  0.810526
# 1            2  0.776842
# 2            3  0.938947
# 3            4  0.621053
# 4            5  0.680000
# ..         ...       ...
# 795         96  0.621053
# 796         97  0.861053
# 797         98  0.905263
# 798         99  0.842105
# 799        100  0.766316
#
# [800 rows x 7 columns]

# %%
## Create left panel ##
height = 45
box_t1 = alt.Chart(
    df_t1_error
).mark_boxplot(
    size=20, outliers=False, ticks=True, opacity=0.5                                     
).encode(
    y=alt.Y('Method:N', title=None),
    x=alt.X('V1:Q', title='Type-I error', scale=alt.Scale(domain=(0, 0.4))),
    color='Method:N'
).properties(
    height=height,
    width=300
)

point_t1 = alt.Chart(
    df_t1_error
).mark_point(
    size=40, opacity=0.3
).encode(
    y=alt.Y('Method:N', title=None),
    x=alt.X('V1:Q', 
            title='Type-I error',scale=alt.Scale(domain=(0, 0.4))),
    color='Method:N'
).properties(
    height=height,
    width=300
).transform_sample(
    70
)

rule1 = alt.Chart(pd.DataFrame({
  'V1': [0.05],
})).mark_rule(size=1.5, strokeDash=[5, 5]).encode(
  x=alt.X('V1:Q', axis=alt.Axis(tickCount=5)),
  color = alt.value('black')
)

fig_t1_Mi = point_t1 + box_t1 + rule1
fig_t1_Mi = fig_t1_Mi.facet(
    row=alt.Row('correlation:O', title='Correlation strength',
                sort='descending')
).properties(
    title="A"
)

## create right panel ##
box_auc = alt.Chart(
    df_auc
).mark_boxplot(
    size=20, outliers=False, ticks=True, opacity=0.5
).encode(
    y=alt.Y('Method:N', axis=alt.Axis(labels=False, title=None)),
    x=alt.X('V1:Q', title='AUC', scale=alt.Scale(domain=(0.5, 1))),
    color='Method:N'
).properties(
    height=height,
    width=300
)

point_auc = alt.Chart(
    df_auc
).mark_point(
    size=40, opacity=0.3
).encode(
    y=alt.Y('Method:N', axis=alt.Axis(labels=False, title=None)),
    x=alt.X('V1:Q',  title='AUC', scale=alt.Scale(domain=(0.5, 1))),
    color='Method:N'
).properties(
    height=height,
    width=300
).transform_sample(
    70
)


rule2 = alt.Chart(pd.DataFrame({
  'V1': [0.5],
  'nominal_error': ['nominal Type-1 error'],
  'color': ['black']
})).mark_rule(size=1.5, color='black').encode(
  x='V1:Q'
)

fig_auc_Mi = point_auc + box_auc + rule2
fig_auc_Mi = fig_auc_Mi.facet(
    row=alt.Row('correlation:O',
                title=None,
                sort='descending',
                header=alt.Header(title=None, labels=False))
).properties(
    title="B"
)

my_font = 'Helvetica'
fig = alt.hconcat(
    fig_t1_Mi,
    fig_auc_Mi
).configure_axis(
    grid=False, 
    titleFont=my_font,
    titleFontWeight='normal',
    labelFont=my_font,
    labelFontSize=16,
    titleFontSize=20
).configure_header(
    titleFont=my_font,
    titleFontWeight='normal',
    labelFont=my_font,
    titleFontSize=20,
    labelFontSize=16
).configure_view(
    strokeWidth=0
).configure_title(
    font=my_font,
    fontSize=20
).configure_legend(
    titleFontSize=20,
    labelFontSize=20,
    labelLimit=0,
    orient='none',
    legendX=150,
    legendY=175
)

# fig.save('figure_1.svg')
# fig.save('figure_1.png', scale_factor=3)
fig
# Out:
# alt.HConcatChart(...)

# %% [markdown]
# ## Figure 2

# %%
list(res_path.glob('*100--1000*.csv'))
# Out:
# [PosixPath('../results/results_csv/simulation_results_blocks_100_dnn_dnn_py_perm_100--1000.csv'),
#  PosixPath('../results/results_csv/type1error_blocks_100_dnn_dnn_py_perm_100--1000.csv'),
#  PosixPath('../results/results_csv/AUC_blocks_100_dnn_dnn_py_perm_100--1000.csv')]

# %%
df_auc_range = pd.read_csv(res_path / 'AUC_blocks_100_dnn_dnn_py_perm_100--1000.csv')
df_t1_error_range = pd.read_csv(res_path / 'type1error_blocks_100_dnn_dnn_py_perm_100--1000.csv')

# %%
scenarios = ['Classification', 'Plain linear', 'Regression with ReLu', 'Interactions only', 'Main effects and Interactions']
            
df_t1_error_range_agg = df_t1_error_range.groupby(['Method', 'correlation', 'n_samples', 'prob_data'])['V2'].agg([np.mean, np.std]).reset_index()
df_t1_error_range_agg['ymin'] = df_t1_error_range_agg['mean'] - df_t1_error_range_agg['std']
df_t1_error_range_agg['ymax'] = df_t1_error_range_agg['mean'] + df_t1_error_range_agg['std']
df_t1_error_range_agg = df_t1_error_range_agg.set_index('prob_data').loc[scenarios].reset_index()
df_t1_error_range_agg.loc[::10]
# Out:
#                         prob_data       Method  correlation  n_samples  \
# 0                  Classification      CPI-DNN          0.8        100
# 10                 Classification  Permfit-DNN          0.8        100
# 20                   Plain linear      CPI-DNN          0.8        100
# 30                   Plain linear  Permfit-DNN          0.8        100
# 40           Regression with ReLu      CPI-DNN          0.8        100
# 50           Regression with ReLu  Permfit-DNN          0.8        100
# 60              Interactions only      CPI-DNN          0.8        100
# 70              Interactions only  Permfit-DNN          0.8        100
# 80  Main effects and Interactions      CPI-DNN          0.8        100
# 90  Main effects and Interactions  Permfit-DNN          0.8        100
#
#         mean       std      ymin      ymax
# 0   0.039000  0.036716  0.002284  0.075716
# 10  0.125333  0.068020  0.057313  0.193353
# 20  0.034667  0.030675  0.003992  0.065342
# 30  0.243333  0.092539  0.150795  0.335872
# 40  0.036000  0.035353  0.000647  0.071353
# 50  0.170333  0.075789  0.094544  0.246122
# 60  0.043333  0.037754  0.005579  0.081087
# 70  0.095333  0.067006  0.028327  0.162339
# 80  0.046667  0.037003  0.009663  0.083670
# 90  0.103000  0.066683  0.036317  0.169683

# %%
df_auc_range['ymin'] = df_auc_range['mean'] - df_auc_range['sd']
df_auc_range['ymax'] = df_auc_range['mean'] + df_auc_range['sd']
df_auc_range = df_auc_range.set_index('prob_data').loc[scenarios].reset_index()

# %%
def plot_fig2(df_data_t1, df_data_auc, title_x=None, title_facet=None, title_y=None,
              title_subfig1='', title_subfig2='', height=110, width=240):
    rule1 = alt.Chart(pd.DataFrame({
      'V1': [0.05],
      'Method': ['Type-I error nominal rate'],
      'color': ['black']
    })).mark_rule(size=1.5, strokeDash=[5, 5]).encode(
      y='V1:Q',
      color = alt.value('black')
    )

    points = alt.Chart(
        df_data_t1
    ).mark_point(
    ).encode(
        x='n_samples',
        y='mean',
        color='Method'
    )

    err = alt.Chart(
        df_data_t1
    ).mark_errorband(
    ).encode(
        x='n_samples',
        y=alt.Y('ymin', title=''),
        y2=alt.Y2('ymax', title=None),
        color='Method'
    )

    lines = alt.Chart(
        df_data_t1
    ).mark_line(
    ).encode(
        x=alt.X('n_samples', title=None),
        y=alt.Y('mean', title=title_y[1]),
        color='Method'
    ).properties(
        height=height,
        width=width
    )

    fig_t1_err_range = (points + err + lines + rule1).facet(
        column=alt.Column('prob_data:N', title=title_facet)
    ).properties(title=title_subfig1)

    ### AUC ###
    rule2 = alt.Chart(pd.DataFrame({
      'V1': [0.5],
      'Method': ['Type-I error nominal rate'],
      'color': ['black']
    })).mark_rule(size=1.5).encode(
      y='V1:Q',
      color = alt.value('black')
    )

    points_auc = alt.Chart(
        df_data_auc
    ).mark_point(
    ).encode(
        x=alt.X('n_samples', title=title_x),
        y=alt.Y('mean', scale=alt.Scale(domain=[0.4, 1.0])),
        color='Method'
    )

    err_auc = alt.Chart(
        df_data_auc
    ).mark_errorband(
    ).encode(
        x=alt.X('n_samples', title=title_x),
        y=alt.Y('ymin', title='', scale=alt.Scale(domain=[0.4, 1.0])),
        y2=alt.Y2('ymax', title=None),
        color='Method'
    )

    lines_auc = alt.Chart(
        df_data_auc
    ).mark_line(
    ).encode(
        x=alt.X('n_samples', title=title_x),
        y=alt.Y('mean', title=title_y[0], scale=alt.Scale(domain=[0.4, 1.0])),
        color='Method'
    ).properties(
        height=height,
        width=width
    )

    fig_auc_range = (points_auc + err_auc + lines_auc + rule2).facet(
        column=alt.Column('prob_data:N', title=None,
                          header=alt.Header(labels=False))).properties(
        title=title_subfig2
    )
    fig2 = alt.vconcat(fig_t1_err_range, fig_auc_range)
    return fig2

prob_data = [('Classification', None, None, ('AUC', 'Type-I error'), 'A', 'B'),
             ('Plain linear', None, None, (None, None), ' ', ' '),
             ('Regression with ReLu', "Number of samples", "Scenario", (None, None), ' ', ' '),
             ('Interactions only', None, None, (None, None), ' ', ' '),
             ('Main effects and Interactions', None, None, (None, None), ' ', ' ')]
list_figs = []
for el in prob_data:
    df_t1_tmp = df_t1_error_range_agg[df_t1_error_range_agg['prob_data'] == el[0]]
    df_auc_tmp = df_auc_range[df_auc_range['prob_data'] == el[0]]
    list_figs.append(plot_fig2(df_t1_tmp, df_auc_tmp, el[1], el[2], el[3], el[4], el[5]))

fig2 = alt.hconcat(
    list_figs[0],
    list_figs[1],
    list_figs[2],
    list_figs[3],
    list_figs[4]
).configure(
    concat=alt.CompositionConfig(spacing=5)
)

my_font = 'Helvetica'
fig2 = fig2.configure_axis(
    grid=True, 
    titleFont=my_font,
    titleFontWeight='normal',
    labelFont=my_font,
    labelFontSize=24,
    titleFontSize=28,
    titlePadding=20
).configure_header(
    titleFont=my_font,
    titleFontWeight='normal',
    labelFont=my_font,
    titleFontSize=28,
    labelFontSize=24
).configure_view(
    strokeWidth=0
).configure_title(
    font=my_font,
    fontSize=28
).configure_legend(
    titleFontSize=28,
    labelFontSize=24,
    orient='none',
    columns=2,
    legendX=900,
    legendY=-110,
    labelLimit=0
)

# fig2.save('figure_2.svg')
# fig2.save('figure_2.png', scale_factor=3)
fig2
# Out:
# alt.HConcatChart(...)

# %% [markdown]
# ## Figure 3

# %%
list(res_path.glob('*all*.csv'))
# Out:
# [PosixPath('../results/results_csv/simulation_results_blocks_100_allMethods_pred_final.csv'),
#  PosixPath('../results/results_csv/Result_single_FREQ_all_imp_outer_10_inner.csv'),
#  PosixPath('../results/results_csv/power_blocks_100_allMethods_pred_imp_final.csv'),
#  PosixPath('../results/results_csv/type1error_blocks_100_allMethods_pred_imp_final.csv'),
#  PosixPath('../results/results_csv/AUC_blocks_100_allMethods_pred_imp_final_withoutPval.csv'),
#  PosixPath('../results/results_csv/Result_single_10Fold_FREQ_all_imp.csv'),
#  PosixPath('../results/results_csv/time_bars_blocks_100_allMethods_pred_imp_final.csv'),
#  PosixPath('../results/results_csv/AUC_blocks_100_allMethods_pred_imp_final_withPval.csv')]

# %%
df_auc_all = pd.read_csv(res_path / 'AUC_blocks_100_allMethods_pred_imp_final_withPval.csv')
df_auc_all = df_auc_all.rename(columns={'method': 'Method', 'prob_data':'Problem Data'})
df_auc_all['Problem Data'] = df_auc_all['Problem Data'].map({'classification':'Classification',
                                                             'regression': 'Plain linear',
                                                             'regression_relu': 'Regression with ReLu',
                                                             'regression_product': 'Interactions only',
                                                             'regression_combine': 'Main effects and Interactions'})
df_auc_all['Method'] = df_auc_all['Method'].map({'Marg':'Marginal',
                                                 'd0CRT': 'd0CRT',
                                                 'Permfit-DNN': 'Permfit-DNN',
                                                 'CPI-DNN': 'CPI-DNN',
                                                 'CPI-RF': 'CPI-RF',
                                                 'Strobl': 'Conditional-RF',
                                                 'lazyvi': 'Lazy VI',
                                                 'cpi_knockoff': 'cpi-knockoff',
                                                 'loco': 'LOCO'})

df_t1_error_all = pd.read_csv(res_path / 'type1error_blocks_100_allMethods_pred_imp_final.csv')
df_t1_error_all = df_t1_error_all.rename(columns={'method': 'Method', 'prob_data':'Problem Data'})
# df_t1_error_all['Problem Data'] = df_t1_error_all['Problem Data'].map({'classification':'Classification',
#                                                              'regression': 'Plain linear',
#                                                              'regression_relu': 'Regression with ReLu',
#                                                              'regression_product': 'Interactions only',
#                                                              'regression_combine': 'Main effects and Interactions'})
# df_t1_error_all['Method'] = df_t1_error_all['Method'].map({'Marg':'Marginal',
#                                                            'd0CRT': 'd0CRT',
#                                                            'Permfit-DNN': 'Permfit-DNN',
#                                                            'CPI-DNN': 'CPI-DNN',
#                                                            'CPI-RF': 'CPI-RF',
#                                                            'Strobl': 'Conditional-RF',
#                                                            'lazyvi': 'Lazy VI',
#                                                            'cpi_knockoff': 'cpi-knockoff',
#                                                            'loco': 'LOCO'})

# %%
df_auc_all.sample(10)
# Out:
#               Method  correlation  n_samples                   Problem Data  \
# 3427          CPI-RF          0.8       1000           Regression with ReLu
# 4103            LOCO          0.8       1000                   Plain linear
# 3654    cpi-knockoff          0.8       1000                   Plain linear
# 1789  Conditional-RF          0.8       1000  Main effects and Interactions
# 4249            LOCO          0.8       1000  Main effects and Interactions
# 332      Permfit-DNN          0.8       1000              Interactions only
# 2041           d0CRT          0.8       1000                 Classification
# 99       Permfit-DNN          0.8       1000                 Classification
# 1881  Conditional-RF          0.8       1000              Interactions only
# 4349            LOCO          0.8       1000              Interactions only
#
#       iteration       prob_type        V1
# 3427         28      regression  0.630000
# 4103          4      regression  0.513333
# 3654         55      regression  0.646667
# 1789         90      regression  0.745000
# 4249         50      regression  0.483333
# 332          33      regression  0.983333
# 2041         42  classification  0.870000
# 99          100  classification  0.746667
# 1881         82      regression  0.846667
# 4349         50      regression  0.848333

# %%
df_t1_error_all.sample(10)
# Out:
#             Method  correlation  n_samples                   Problem Data  \
# 3155        CPI-RF          0.8       1000                   Plain linear
# 2923       Lazy VI          0.8       1000           Regression with ReLu
# 743        CPI-DNN          0.8       1000  Main effects and Interactions
# 3701  cpi-knockoff          0.8       1000  Main effects and Interactions
# 4026          LOCO          0.8       1000                 Classification
# 27     Permfit-DNN          0.8       1000                 Classification
# 693        CPI-DNN          0.8       1000                   Plain linear
# 2409         d0CRT          0.8       1000           Regression with ReLu
# 2661       Lazy VI          0.8       1000                   Plain linear
# 398    Permfit-DNN          0.8       1000              Interactions only
#
#       iteration       prob_type        V1
# 3155         56      regression  0.000000
# 2923         24      regression  0.000000
# 743          44      regression  0.033333
# 3701          2      regression  0.000000
# 4026         27  classification  0.000000
# 27           28  classification  0.300000
# 693          94      regression  0.000000
# 2409         10      regression  0.066667
# 2661         62      regression  0.033333
# 398          99      regression  0.733333

# %%
def ymin(x):    return np.quantile(x, 0.25)
def ymax(x):    return np.quantile(x, 0.75)
scenarios = ['Classification', 'Plain linear', 'Regression with ReLu', 'Interactions only', 'Main effects and Interactions']
methods = ['Marginal', 'd0CRT', 'Conditional-RF', 'Lazy VI', 'LOCO', 'cpi-knockoff', 'CPI-RF', 'Permfit-DNN', 'CPI-DNN']
df_auc_all_agg = df_auc_all.groupby(['Method', 'Problem Data', 'prob_type'])['V1'].agg([np.mean, ymin, ymax]).reset_index()
df_auc_all_agg = df_auc_all_agg.set_index('Problem Data').loc[scenarios].reset_index()
df_auc_all_agg = df_auc_all_agg.set_index('Method').loc[methods].reset_index()
df_auc_all_agg.head(20)
# Out:
#             Method                   Problem Data       prob_type      mean  \
# 0         Marginal                 Classification  classification  0.635100
# 1         Marginal                   Plain linear      regression  0.641517
# 2         Marginal           Regression with ReLu      regression  0.637183
# 3         Marginal              Interactions only      regression  0.525383
# 4         Marginal  Main effects and Interactions      regression  0.607833
# 5            d0CRT                 Classification  classification  0.856883
# 6            d0CRT                   Plain linear      regression  0.908350
# 7            d0CRT           Regression with ReLu      regression  0.882283
# 8            d0CRT              Interactions only      regression  0.516917
# 9            d0CRT  Main effects and Interactions      regression  0.652783
# 10  Conditional-RF                 Classification  classification  0.687933
# 11  Conditional-RF                   Plain linear      regression  0.705617
# 12  Conditional-RF           Regression with ReLu      regression  0.696942
# 13  Conditional-RF              Interactions only      regression  0.786983
# 14  Conditional-RF  Main effects and Interactions      regression  0.813750
# 15         Lazy VI                 Classification  classification  0.639383
# 16         Lazy VI                   Plain linear      regression  0.923417
# 17         Lazy VI           Regression with ReLu      regression  0.878200
# 18         Lazy VI              Interactions only      regression  0.914483
# 19         Lazy VI  Main effects and Interactions      regression  0.932450
#
#         ymin      ymax
# 0   0.576250  0.692083
# 1   0.587917  0.707500
# 2   0.575833  0.710417
# 3   0.471667  0.582083
# 4   0.546667  0.671667
# 5   0.827500  0.888333
# 6   0.873333  0.952083
# 7   0.850000  0.925417
# 8   0.456667  0.575417
# 9   0.598333  0.707500
# 10  0.641250  0.744167
# 11  0.662500  0.752708
# 12  0.651250  0.739167
# 13  0.761250  0.821667
# 14  0.776667  0.855417
# 15  0.595000  0.697083
# 16  0.897083  0.958333
# 17  0.845417  0.918333
# 18  0.895000  0.957083
# 19  0.911667  0.960000

# %%
df_t1_error_all_agg = df_t1_error_all.groupby(['Method', 'Problem Data', 'prob_type'])['V1'].agg([np.mean, ymin, ymax]).reset_index()
df_t1_error_all_agg = df_t1_error_all_agg.set_index('Problem Data').loc[scenarios].reset_index()
df_t1_error_all_agg = df_t1_error_all_agg.set_index('Method').loc[methods].reset_index()
df_t1_error_all_agg.head(20)
# Out:
#             Method                   Problem Data       prob_type      mean  \
# 0         Marginal                 Classification  classification  0.671000
# 1         Marginal                   Plain linear      regression  0.709333
# 2         Marginal           Regression with ReLu      regression  0.680333
# 3         Marginal              Interactions only      regression  0.075000
# 4         Marginal  Main effects and Interactions      regression  0.367000
# 5            d0CRT                 Classification  classification  0.051333
# 6            d0CRT                   Plain linear      regression  0.079667
# 7            d0CRT           Regression with ReLu      regression  0.049333
# 8            d0CRT              Interactions only      regression  0.026000
# 9            d0CRT  Main effects and Interactions      regression  0.025667
# 10  Conditional-RF                 Classification  classification  0.402333
# 11  Conditional-RF                   Plain linear      regression  0.476667
# 12  Conditional-RF           Regression with ReLu      regression  0.376667
# 13  Conditional-RF              Interactions only      regression  0.348000
# 14  Conditional-RF  Main effects and Interactions      regression  0.388000
# 15         Lazy VI                 Classification  classification  0.232333
# 16         Lazy VI                   Plain linear      regression  0.092333
# 17         Lazy VI           Regression with ReLu      regression  0.090333
# 18         Lazy VI              Interactions only      regression  0.783000
# 19         Lazy VI  Main effects and Interactions      regression  0.704667
#
#         ymin      ymax
# 0   0.566667  0.800000
# 1   0.625000  0.833333
# 2   0.566667  0.800000
# 3   0.033333  0.100000
# 4   0.266667  0.466667
# 5   0.033333  0.066667
# 6   0.033333  0.100000
# 7   0.033333  0.066667
# 8   0.000000  0.033333
# 9   0.000000  0.033333
# 10  0.333333  0.466667
# 11  0.400000  0.566667
# 12  0.333333  0.433333
# 13  0.291667  0.433333
# 14  0.325000  0.433333
# 15  0.066667  0.333333
# 16  0.058333  0.133333
# 17  0.033333  0.133333
# 18  0.758333  1.000000
# 19  0.358333  1.000000

# %%
marker_size = 200
err_size = 2
height = 175
width= 125
scheme = 'tableau10'
points_a = alt.Chart(
    df_t1_error_all_agg
).mark_point(
    size=marker_size, opacity=1, fill='white'
).encode(
    x=alt.X('Problem Data:O', title=None, scale=alt.Scale(domain=scenarios[::-1]),
            axis=alt.Axis(labels=False, title=None, tickSize=0)),
    y=alt.Y('mean:Q', 
            title='Type-I error',scale=alt.Scale(domain=(0, 1.0))),
    color=alt.Color('Problem Data:O', title='Scenario',
                    scale=alt.Scale(scheme=scheme, domain=scenarios[::-1]))
).properties(
    height=height,
    width=width
)

error_a = alt.Chart(
    df_t1_error_all_agg
).mark_errorbar(
    opacity=1
).encode(
    x=alt.X('Problem Data:O', title=None, scale=alt.Scale(domain=scenarios[::-1])),
    y=alt.Y('ymin:Q',  title='Type-I error',scale=alt.Scale(domain=(0, 1.0))),
    y2=alt.Y2('ymax:Q', title='Type-I error'),
    color=alt.Color('Problem Data:O', title='Scenario',
                    scale=alt.Scale(scheme=scheme, domain=scenarios[::-1])),
    strokeWidth=alt.value(err_size)
).properties(
    height=height,
    width=width
)

rule1= alt.Chart(pd.DataFrame({
  'V1': [0.05],
  'Problem Data': ['Type-I error nominal rate'],
  'color': ['black']
})).mark_rule(size=1.5, color='black', strokeDash=[5, 5]).encode(
  y='V1:Q',
  color = alt.value('black')
)

fig_t1_all = (error_a + points_a + rule1).facet(
    column=alt.Column('Method:O', sort=methods[::-1])
).properties(title='A')

## AUC ##
points_b = alt.Chart(
    df_auc_all_agg
    
).mark_point(
    size=marker_size, opacity=1, fill='white'
).encode(
    x=alt.X('Problem Data:O', title=None, scale=alt.Scale(domain=scenarios[::-1])),
    y=alt.Y('mean:Q', 
            title='AUC',scale=alt.Scale(domain=(0.4, 1.0))),
    color=alt.Color('Problem Data:O', title='Scenario',
                    scale=alt.Scale(scheme=scheme, domain=scenarios[::-1]))
).properties(
    height=height,
    width=width
)

error_b = alt.Chart(
    df_auc_all_agg
).mark_errorbar(
    size=err_size, opacity=1
).encode(
    x=alt.X('Problem Data:N',
            title=None,
            scale=alt.Scale(domain=scenarios[::-1]),
            axis=alt.Axis(labels=False, title=None, tickSize=0)),
    y=alt.Y('ymin:Q',  title='AUC', scale=alt.Scale(domain=(0.4, 1.0))),
    y2=alt.Y2('ymax:Q', title='AUC'),
    color=alt.Color('Problem Data:O', title='Scenario',
                    scale=alt.Scale(scheme=scheme, domain=scenarios[::-1])),
    strokeWidth=alt.value(err_size)
).properties(
    height=height,
    width=width
)

rule2 = alt.Chart(pd.DataFrame({
  'V1': [0.5],
  'Problem Data': ['Type-I error nominal rate'],
  'color': ['black']
})).mark_rule(size=1.5, color='black').encode(
  y='V1:Q'
)

fig_auc_all = (error_b + points_b + rule2).facet(
    column=alt.Column('Method:O', title=None, sort=methods[::-1],
                header=alt.Header(title=None, labels=False))
).properties(title='B')

# fig_3 = fig_t1_all | fig_auc_all

my_font = 'Helvetica'
fig3 = alt.vconcat(
    fig_t1_all,
    fig_auc_all
).configure_axis(
    grid=True, 
    titleFont=my_font,
    titleFontWeight='normal',
    labelFont=my_font,
    labelFontSize=28,
    titleFontSize=32,
    labelLimit=0,
    titlePadding=20
).configure_header(
    titleFont=my_font,
    titleFontWeight='normal',
    labelFont=my_font,
    titleFontSize=32,
    labelFontSize=28,
    labelPadding=35,
).configure_view(
    strokeWidth=0
).configure_title(
    font=my_font,
    fontSize=28
).configure_legend(
    titleFontSize=28,
    labelFontSize=24,
    orient ='top',
#     columns=3,
    labelLimit=0,
    columnPadding=45,
    symbolSize=150,
)

# fig3.save('figure_3.svg')
# fig3.save('figure_3.png', scale_factor=3)
fig3
# Out:
# alt.VConcatChart(...)
